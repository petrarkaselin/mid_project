# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('../data/TMDB_movie_dataset_v1.csv')

# %%
df.head(60)
# Out:
#     Unnamed: 0      id                                              title  \
# 0           15  299534                                  Avengers: Endgame
# 1           18  475557                                              Joker
# 2           57  634649                            Spider-Man: No Way Home
# 3          117  299537                                     Captain Marvel
# 4          121  429617                          Spider-Man: Far From Home
# 5          180  466272                     Once Upon a Time… in Hollywood
# 6          210  530915                                               1917
# 7          220  546554                                         Knives Out
# 8          282   76600                           Avatar: The Way of Water
# 9          289  458156                  John Wick: Chapter 3 - Parabellum
# 10         295  495764  Birds of Prey (and the Fantabulous Emancipatio...
# 11         307  508442                                               Soul
# ...

# %%
df.shape
# Out:
# (30607, 24)

# %%
df['id'].nunique()
# Out:
# 30607

# %%
df.isna().sum()
# Out:
# Unnamed: 0                  0
# id                          0
# title                       0
# vote_average                0
# vote_count                  0
# status                      0
# release_date                0
# revenue                     0
# runtime                     0
# adult                       0
# backdrop_path           13221
# budget                      0
# homepage                21485
# imdb_id                 13925
# original_language           0
# original_title              0
# overview                  855
# popularity                  0
# poster_path              2136
# tagline                 22186
# genres                   9141
# production_companies     7506
# production_countries        0
# spoken_languages         6167
# dtype: int64

# %%
df.dtypes
# Out:
# id                        int64
# title                    object
# vote_average            float64
# vote_count                int64
# status                   object
# release_date             object
# revenue                   int64
# runtime                   int64
# adult                      bool
# backdrop_path            object
# budget                    int64
# homepage                 object
# imdb_id                  object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# poster_path              object
# tagline                  object
# genres                   object
# production_companies     object
# production_countries     object
# spoken_languages         object
# dtype: object

# %%
df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce')

# %%
df = df[df['production_countries'].str.contains('United States of America', na=False)]

# %%
df = df[df['release_date'].dt.year >= 2019]

# %%
df.to_csv('../data/TMDB_movie_dataset_v1.csv')

# %%
columns_to_drop = ['backdrop_path', 'overview', 'poster_path', 'tagline', 'original_title', 'homepage']
df.drop(columns_to_drop, axis=1, inplace=True)

# %%
df = df[df['vote_count'] > 500]

# %%
display(df[df['production_companies'].isna()])
# Out:
#           id             title  vote_average  vote_count    status  \
# 5645  644090  Love, Guaranteed         6.426         603  Released
#
#      release_date  revenue  runtime  adult  budget     imdb_id  \
# 5645   2020-09-02        0       91  False       0  tt11100856
#
#      original_language  popularity           genres production_companies  \
# 5645                en      10.348  Romance, Comedy                  NaN
#
#           production_countries spoken_languages
# 5645  United States of America          English

# %%
#the companies manually assigned from IMDB
df['production_companies'][5645] = 'Off Camera Entertainment, Industry Entertainment'

# %%
display(df[df['spoken_languages'].isna()])
# Out:
#           id                     title  vote_average  vote_count    status  \
# 1827  594767  Shazam! Fury of the Gods         6.662        2416  Released
# 3110  511809           West Side Story         7.036        1334  Released
#
#      release_date    revenue  runtime  adult     budget     imdb_id  \
# 1827   2023-03-15  133437105      130  False  125000000  tt10151854
# 3110   2021-12-08   74530532      157  False  100000000   tt3581652
#
#      original_language  popularity                   genres  \
# 1827                en     143.169  Comedy, Action, Fantasy
# 3110                en      22.831    Drama, Romance, Crime
#
#                                production_companies      production_countries  \
# 1827  New Line Cinema, The Safran Company, DC Films  United States of America
# 3110     Amblin Entertainment, 20th Century Studios  United States of America
#
#      spoken_languages
# 1827              NaN
# 3110              NaN

# %%
df['spoken_languages'][3110] = 'English'

# %%
df['spoken_languages'][1827] = 'English'
# Out:
# C:\Users\vikto\AppData\Local\Temp\ipykernel_39312\2359834140.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spoken_languages'][1827] = 'English'

# %%
#df['genres'] = df['genres'].str.split(',')

# %%
df['genres'] = df['genres'].str.split(',')
df_exploded = df.explode('genres')

# %%
df_exploded.shape
# Out:
# (1903, 17)

# %%
df.to_csv('version_1.csv')
