# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('../data_raw/TMDB_movie_dataset_v1.csv')

# %%
df.head()
# Out:
#    Unnamed: 0      id                      title  vote_average  vote_count  \
# 0          15  299534          Avengers: Endgame         8.263       23857
# 1          18  475557                      Joker         8.168       23425
# 2          57  634649    Spider-Man: No Way Home         7.990       18299
# 3         117  299537             Captain Marvel         6.843       14657
# 4         121  429617  Spider-Man: Far From Home         7.447       14495
#
#      status release_date     revenue  runtime  adult  ... original_language  \
# 0  Released   2019-04-24  2800000000      181  False  ...                en
# 1  Released   2019-10-01  1074458282      122  False  ...                en
# 2  Released   2021-12-15  1921847111      148  False  ...                en
# 3  Released   2019-03-06  1131416446      124  False  ...                en
# 4  Released   2019-06-28  1131927996      129  False  ...                en
#
#               original_title  \
# ...

# %%
df.shape
# Out:
# (30607, 24)

# %%
df['id'].nunique()
# Out:
# 30607

# %%
df.isna().sum()
# Out:
# Unnamed: 0                  0
# id                          0
# title                       0
# vote_average                0
# vote_count                  0
# status                      0
# release_date                0
# revenue                     0
# runtime                     0
# adult                       0
# backdrop_path           13221
# budget                      0
# homepage                21485
# imdb_id                 13925
# original_language           0
# original_title              0
# overview                  855
# popularity                  0
# poster_path              2136
# tagline                 22186
# genres                   9141
# production_companies     7506
# production_countries        0
# spoken_languages         6167
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0                int64
# id                        int64
# title                    object
# vote_average            float64
# vote_count                int64
# status                   object
# release_date             object
# revenue                   int64
# runtime                   int64
# adult                      bool
# backdrop_path            object
# budget                    int64
# homepage                 object
# imdb_id                  object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# poster_path              object
# tagline                  object
# genres                   object
# production_companies     object
# production_countries     object
# spoken_languages         object
# dtype: object

# %%
df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce')

# %%
#df = df[df['production_countries'].str.contains('United States of America', na=False)]

# %%
#df = df[df['release_date'].dt.year >= 2019]

# %%
#df.to_csv('../data/TMDB_movie_dataset_v1.csv')

# %%
columns_to_drop = ['backdrop_path', 'overview', 'poster_path', 'tagline', 'original_title', 'homepage', 'Unnamed: 0']
df.drop(columns_to_drop, axis=1, inplace=True)

# %%
df = df[df['revenue'] > 0]

# %%
df = df[df['vote_count'] > 100]

# %%
display(df[df['production_companies'].isna()])
# Out:
#           id                          title  vote_average  vote_count  \
# 1275  743439  PAW Patrol: Jet to the Rescue           7.0         158
#
#         status release_date  revenue  runtime  adult  budget     imdb_id  \
# 1275  Released   2020-09-10  1792816       56  False       0  tt13107908
#
#      original_language  popularity             genres production_companies  \
# 1275                en      38.795  Family, Animation                  NaN
#
#                   production_countries spoken_languages
# 1275  Canada, United States of America          English

# %%
#the companies manually assigned from IMDB
df['production_companies'][1275] = 'Off Camera Entertainment, Industry Entertainment'

# %%
display(df[df['spoken_languages'].isna()])
# Out:
#          id                     title  vote_average  vote_count    status  \
# 190  594767  Shazam! Fury of the Gods         6.662        2416  Released
# 349  511809           West Side Story         7.036        1334  Released
#
#     release_date    revenue  runtime  adult     budget     imdb_id  \
# 190   2023-03-15  133437105      130  False  125000000  tt10151854
# 349   2021-12-08   74530532      157  False  100000000   tt3581652
#
#     original_language  popularity                   genres  \
# 190                en     143.169  Comedy, Action, Fantasy
# 349                en      22.831    Drama, Romance, Crime
#
#                               production_companies      production_countries  \
# 190  New Line Cinema, The Safran Company, DC Films  United States of America
# 349     Amblin Entertainment, 20th Century Studios  United States of America
#
#     spoken_languages
# 190              NaN
# 349              NaN

# %%
df['spoken_languages'][190] = 'English'

# %%
df['spoken_languages'][349] = 'English'
# Out:
# C:\Users\vikto\AppData\Local\Temp\ipykernel_11416\3387608621.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['spoken_languages'][349] = 'English'

# %%
#df['genres'] = df['genres'].str.split(',')

# %%
display(df)
# Out:
#           id                      title  vote_average  vote_count    status  \
# 0     299534          Avengers: Endgame         8.263       23857  Released
# 1     475557                      Joker         8.168       23425  Released
# 2     634649    Spider-Man: No Way Home         7.990       18299  Released
# 3     299537             Captain Marvel         6.843       14657  Released
# 4     429617  Spider-Man: Far From Home         7.447       14495  Released
# ...      ...                        ...           ...         ...       ...
# 1527  884184               Consecration         5.825         105  Released
# 1528  893086          The Good Neighbor         6.952         105  Released
# 1532  639247               Dreamkatcher         5.231         104  Released
# 1539  727097                  Archenemy         5.306         103  Released
# 1548  876969              Assassin Club         6.162         102  Released
#
# ...

# %%
#df['genres'] = df['genres'].str.split(',')
#df_exploded = df.explode('genres')

# %%
#df_exploded.shape
# Out:
# (1721, 18)

# %%
df.to_csv('../data_cleaned/cleaned_data_v1.csv')
