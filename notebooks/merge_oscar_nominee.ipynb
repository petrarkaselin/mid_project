# %%
import pandas as pd

# %%
df1 = pd.read_csv('../data_cleaned/cleaned_data_v1.csv').reset_index(drop=True)
df2 = pd.read_csv('../data_cleaned/cleaned_film_oscar_nominee.csv').reset_index(drop=True)

# %%
df1.head()
# Out:
#    Unnamed: 0      id                      title  vote_average  vote_count  \
# 0           0  299534          Avengers: Endgame         8.263       23857
# 1           1  475557                      Joker         8.168       23425
# 2           2  634649    Spider-Man: No Way Home         7.990       18299
# 3           3  299537             Captain Marvel         6.843       14657
# 4           4  429617  Spider-Man: Far From Home         7.447       14495
#
#      status release_date     revenue  runtime  adult     budget     imdb_id  \
# 0  Released   2019-04-24  2800000000      181  False  356000000   tt4154796
# 1  Released   2019-10-01  1074458282      122  False   55000000   tt7286456
# 2  Released   2021-12-15  1921847111      148  False  200000000  tt10872600
# 3  Released   2019-03-06  1131416446      124  False  152000000   tt4154664
# 4  Released   2019-06-28  1131927996      129  False  160000000   tt6320628
#
# ...

# %%
df2.head()
# Out:
#    Unnamed: 0                            title  film_oscar_nominee
# 0           0                   Pain and Glory                   1
# 1           1  Once upon a Time...in Hollywood                   1
# 2           2                   Marriage Story                   1
# 3           3                            Joker                   1
# 4           4                    The Two Popes                   1

# %%
result_df = pd.merge(df1, df2, on='title', how='left')

# %%
result_df['film_oscar_nominee'].fillna(0, inplace=True)

# %%
display(result_df)
# Out:
#          id                      title  vote_average  vote_count    status  \
# 0    299534          Avengers: Endgame         8.263       23857  Released
# 1    475557                      Joker         8.168       23425  Released
# 2    634649    Spider-Man: No Way Home         7.990       18299  Released
# 3    299537             Captain Marvel         6.843       14657  Released
# 4    429617  Spider-Man: Far From Home         7.447       14495  Released
# ..      ...                        ...           ...         ...       ...
# 637  884184               Consecration         5.825         105  Released
# 638  893086          The Good Neighbor         6.952         105  Released
# 639  639247               Dreamkatcher         5.231         104  Released
# 640  727097                  Archenemy         5.306         103  Released
# 641  876969              Assassin Club         6.162         102  Released
#
# ...

# %%
columns_to_drop = ['Unnamed: 0_x', 'Unnamed: 0_y']
result_df.drop(columns_to_drop, axis=1, inplace=True)

# %%
titles_equal = df1['title'].equals(df2['title'])

# %%
result_df.to_csv('../data_cleaned/merged_oscar_nominee.csv')
