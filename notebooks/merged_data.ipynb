# %%
import pandas as pd

# %%
df1 = pd.read_csv('../data_cleaned/merged_nominated_company_data.csv')

# %%
df2 = pd.read_csv('../data_cleaned/merged_oscar_nominee.csv')

# %%
df3 = pd.read_csv('../data_cleaned/cleaned_merged_df.csv')

# %%
df1.head()
# Out:
#        id                      title  vote_average  vote_count    status  \
# 0  299534          Avengers: Endgame         8.263       23857  Released
# 1  475557                      Joker         8.168       23425  Released
# 2  634649    Spider-Man: No Way Home         7.990       18299  Released
# 3  299537             Captain Marvel         6.843       14657  Released
# 4  429617  Spider-Man: Far From Home         7.447       14495  Released
#
#   release_date     revenue  runtime  adult     budget     imdb_id  \
# 0   2019-04-24  2800000000      181  False  356000000   tt4154796
# 1   2019-10-01  1074458282      122  False   55000000   tt7286456
# 2   2021-12-15  1921847111      148  False  200000000  tt10872600
# 3   2019-03-06  1131416446      124  False  152000000   tt4154664
# 4   2019-06-28  1131927996      129  False  160000000   tt6320628
#
#   original_language  popularity                              genres  \
# 0                en      91.756  Adventure, Science Fiction, Action
# 1                en      54.522              Crime, Thriller, Drama
# 2                en     186.065  Action, Adventure, Science Fiction
# 3                en      50.399  Action, Adventure, Science Fiction
# 4                en      49.913  Action, Adventure, Science Fiction
#
#                                 production_companies  \
# 0                                     Marvel Studios
# 1  Warner Bros. Pictures, Joint Effort, Village R...
# 2  Marvel Studios, Pascal Pictures, Columbia Pict...
# 3                                     Marvel Studios
# 4  Marvel Studios, Pascal Pictures, Columbia Pict...
#
#                production_countries                        spoken_languages  \
# 0          United States of America                English, Japanese, Xhosa
# 1  Canada, United States of America                                 English
# 2          United States of America                        English, Tagalog
# 3          United States of America                                 English
# 4          United States of America  Czech, Dutch, English, German, Italian
#
#    company_nominated
# 0                  0
# 1                  1
# 2                  0
# 3                  0
# 4                  0

# %%
df2.head()
# Out:
#        id                      title  vote_average  vote_count    status  \
# 0  299534          Avengers: Endgame         8.263       23857  Released
# 1  475557                      Joker         8.168       23425  Released
# 2  634649    Spider-Man: No Way Home         7.990       18299  Released
# 3  299537             Captain Marvel         6.843       14657  Released
# 4  429617  Spider-Man: Far From Home         7.447       14495  Released
#
#   release_date     revenue  runtime  adult     budget     imdb_id  \
# 0   2019-04-24  2800000000      181  False  356000000   tt4154796
# 1   2019-10-01  1074458282      122  False   55000000   tt7286456
# 2   2021-12-15  1921847111      148  False  200000000  tt10872600
# 3   2019-03-06  1131416446      124  False  152000000   tt4154664
# 4   2019-06-28  1131927996      129  False  160000000   tt6320628
#
#   original_language  popularity                              genres  \
# 0                en      91.756  Adventure, Science Fiction, Action
# 1                en      54.522              Crime, Thriller, Drama
# 2                en     186.065  Action, Adventure, Science Fiction
# 3                en      50.399  Action, Adventure, Science Fiction
# 4                en      49.913  Action, Adventure, Science Fiction
#
#                                 production_companies  \
# 0                                     Marvel Studios
# 1  Warner Bros. Pictures, Joint Effort, Village R...
# 2  Marvel Studios, Pascal Pictures, Columbia Pict...
# 3                                     Marvel Studios
# 4  Marvel Studios, Pascal Pictures, Columbia Pict...
#
#                production_countries                        spoken_languages  \
# 0          United States of America                English, Japanese, Xhosa
# 1  Canada, United States of America                                 English
# 2          United States of America                        English, Tagalog
# 3          United States of America                                 English
# 4          United States of America  Czech, Dutch, English, German, Italian
#
#    film_oscar_nominee
# 0                 1.0
# 1                 1.0
# 2                 1.0
# 3                 0.0
# 4                 0.0

# %%
columns_to_drop = ['Unnamed: 0']
df2.drop(columns_to_drop, axis=1, inplace=True)

# %%
columns_to_drop = ['Unnamed: 0', 'Unnamed: 0.1']
df3.drop(columns_to_drop, axis=1, inplace=True)

# %%
df3.head()
# Out:
#        id                      title  vote_average  vote_count    status  \
# 0  299534          Avengers: Endgame         8.263       23857  Released
# 1  475557                      Joker         8.168       23425  Released
# 2  634649    Spider-Man: No Way Home         7.990       18299  Released
# 3  299537             Captain Marvel         6.843       14657  Released
# 4  429617  Spider-Man: Far From Home         7.447       14495  Released
#
#   release_date     revenue  runtime  adult     budget     imdb_id  \
# 0   2019-04-24  2800000000      181  False  356000000   tt4154796
# 1   2019-10-01  1074458282      122  False   55000000   tt7286456
# 2   2021-12-15  1921847111      148  False  200000000  tt10872600
# 3   2019-03-06  1131416446      124  False  152000000   tt4154664
# 4   2019-06-28  1131927996      129  False  160000000   tt6320628
#
#   original_language  popularity                              genres  \
# 0                en      91.756  Adventure, Science Fiction, Action
# 1                en      54.522              Crime, Thriller, Drama
# 2                en     186.065  Action, Adventure, Science Fiction
# 3                en      50.399  Action, Adventure, Science Fiction
# 4                en      49.913  Action, Adventure, Science Fiction
#
#                                 production_companies  \
# 0                                     Marvel Studios
# 1  Warner Bros. Pictures, Joint Effort, Village R...
# 2  Marvel Studios, Pascal Pictures, Columbia Pict...
# 3                                     Marvel Studios
# 4  Marvel Studios, Pascal Pictures, Columbia Pict...
#
#                production_countries                        spoken_languages  \
# 0          United States of America                English, Japanese, Xhosa
# 1  Canada, United States of America                                 English
# 2          United States of America                        English, Tagalog
# 3          United States of America                                 English
# 4          United States of America  Czech, Dutch, English, German, Italian
#
#   license
# 0   PG-13
# 1       R
# 2   PG-13
# 3   PG-13
# 4     NaN

# %%
df3.isna().sum()
# Out:
# id                      0
# title                   0
# vote_average            0
# vote_count              0
# status                  0
# release_date            0
# revenue                 0
# runtime                 0
# adult                   0
# budget                  0
# imdb_id                 0
# original_language       0
# popularity              0
# genres                  0
# production_companies    0
# production_countries    0
# spoken_languages        0
# license                 0
# dtype: int64

# %%
df3['license'].fillna('unknown', inplace=True)

# %%
result_1 = pd.merge(df2, df1[['title', 'company_nominated']], on='title', how='left')

# %%
result_df = pd.merge(result_1, df3[['title', 'license']], on='title', how='left')

# %%
result_df
# Out:
#          id                      title  vote_average  vote_count    status  \
# 0    299534          Avengers: Endgame         8.263       23857  Released
# 1    475557                      Joker         8.168       23425  Released
# 2    634649    Spider-Man: No Way Home         7.990       18299  Released
# 3    299537             Captain Marvel         6.843       14657  Released
# 4    429617  Spider-Man: Far From Home         7.447       14495  Released
# ..      ...                        ...           ...         ...       ...
# 647  884184               Consecration         5.825         105  Released
# 648  893086          The Good Neighbor         6.952         105  Released
# 649  639247               Dreamkatcher         5.231         104  Released
# 650  727097                  Archenemy         5.306         103  Released
# 651  876969              Assassin Club         6.162         102  Released
#
#     release_date     revenue  runtime  adult     budget     imdb_id  \
# 0     2019-04-24  2800000000      181  False  356000000   tt4154796
# 1     2019-10-01  1074458282      122  False   55000000   tt7286456
# 2     2021-12-15  1921847111      148  False  200000000  tt10872600
# 3     2019-03-06  1131416446      124  False  152000000   tt4154664
# 4     2019-06-28  1131927996      129  False  160000000   tt6320628
# ..           ...         ...      ...    ...        ...         ...
# 647   2023-02-09     1504289       90  False          0  tt14993352
# 648   2022-06-17       94909       97  False        105  tt14349032
# 649   2020-06-24      375836       85  False          0  tt10553210
# 650   2020-11-30      136240       90  False          0  tt11274100
# 651   2023-02-24      188292      113  False          0   tt7720142
#
#     original_language  popularity                                    genres  \
# 0                  en      91.756        Adventure, Science Fiction, Action
# 1                  en      54.522                    Crime, Thriller, Drama
# 2                  en     186.065        Action, Adventure, Science Fiction
# 3                  en      50.399        Action, Adventure, Science Fiction
# 4                  en      49.913        Action, Adventure, Science Fiction
# ..                ...         ...                                       ...
# 647                en      48.774                          Horror, Thriller
# 648                en      13.842                                  Thriller
# 649                en       7.720                          Horror, Thriller
# 650                en       8.290  Action, Thriller, Crime, Science Fiction
# 651                en      36.325                 Action, Mystery, Thriller
#
#                                   production_companies  \
# 0                                       Marvel Studios
# 1    Warner Bros. Pictures, Joint Effort, Village R...
# 2    Marvel Studios, Pascal Pictures, Columbia Pict...
# 3                                       Marvel Studios
# 4    Marvel Studios, Pascal Pictures, Columbia Pict...
# ..                                                 ...
# 647     AGC Studios, Bigscope Films, Moonriver Content
# 648                 Forma Pro Films, Altit Media Group
# 649                            Taylor Lane Productions
# 650  SpectreVision, Legion M, RLJ Entertainment, He...
# 651       Film Bridge International, The Motus Studios
#
#                          production_countries  \
# 0                    United States of America
# 1            Canada, United States of America
# 2                    United States of America
# 3                    United States of America
# 4                    United States of America
# ..                                        ...
# 647  United Kingdom, United States of America
# 648          United States of America, Latvia
# 649                  United States of America
# 650                  United States of America
# 651           Italy, United States of America
#
#                            spoken_languages  film_oscar_nominee  \
# 0                  English, Japanese, Xhosa                 1.0
# 1                                   English                 1.0
# 2                          English, Tagalog                 1.0
# 3                                   English                 0.0
# 4    Czech, Dutch, English, German, Italian                 0.0
# ..                                      ...                 ...
# 647                                 English                 0.0
# 648                                 English                 0.0
# 649                                 English                 0.0
# 650                                 English                 0.0
# 651                                 English                 0.0
#
#      company_nominated  license
# 0                    0    PG-13
# 1                    1        R
# 2                    0    PG-13
# 3                    0    PG-13
# 4                    0  unknown
# ..                 ...      ...
# 647                  0  unknown
# 648                  0  unknown
# 649                  0  unknown
# 650                  0  unknown
# 651                  0  unknown
#
# [641 rows x 20 columns]

# %%
result_df.isna().sum()
# Out:
# id                      0
# title                   0
# vote_average            0
# vote_count              0
# status                  0
# release_date            0
# revenue                 0
# runtime                 0
# adult                   0
# budget                  0
# imdb_id                 0
# original_language       0
# popularity              0
# genres                  0
# production_companies    0
# production_countries    0
# spoken_languages        0
# film_oscar_nominee      0
# company_nominated       0
# license                 0
# dtype: int64

# %%
duplicates = result_df[result_df.duplicated(subset='title', keep=False)]

# %%
duplicates
# Out:
# Empty DataFrame
# Columns: [id, title, vote_average, vote_count, status, release_date, revenue, runtime, adult, budget, imdb_id, original_language, popularity, genres, production_companies, production_countries, spoken_languages, film_oscar_nominee, company_nominated, license]
# Index: []

# %%
result_df = result_df.drop_duplicates(subset='title', keep='first')

# %%
result_df.to_csv('../data_cleaned/merged_data.csv')
