# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('../data_cleaned/cleaned_data_v1.csv')

# %%
df1
# Out:
#      Unnamed: 0      id                      title  vote_average  vote_count  \
# 0             0  299534          Avengers: Endgame         8.263       23857
# 1             1  475557                      Joker         8.168       23425
# 2             2  634649    Spider-Man: No Way Home         7.990       18299
# 3             3  299537             Captain Marvel         6.843       14657
# 4             4  429617  Spider-Man: Far From Home         7.447       14495
# ..          ...     ...                        ...           ...         ...
# 637        1527  884184               Consecration         5.825         105
# 638        1528  893086          The Good Neighbor         6.952         105
# 639        1532  639247               Dreamkatcher         5.231         104
# 640        1539  727097                  Archenemy         5.306         103
# 641        1548  876969              Assassin Club         6.162         102
#
# ...

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'id', 'title', 'vote_average', 'vote_count', 'status',
#        'release_date', 'revenue', 'runtime', 'adult', 'budget', 'imdb_id',
#        'original_language', 'popularity', 'genres', 'production_companies',
#        'production_countries', 'spoken_languages'],
#       dtype='object')

# %%
df1
# Out:
#      Unnamed: 0      id                      title  vote_average  vote_count  \
# 0             0  299534          Avengers: Endgame         8.263       23857
# 1             1  475557                      Joker         8.168       23425
# 2             2  634649    Spider-Man: No Way Home         7.990       18299
# 3             3  299537             Captain Marvel         6.843       14657
# 4             4  429617  Spider-Man: Far From Home         7.447       14495
# ..          ...     ...                        ...           ...         ...
# 637        1527  884184               Consecration         5.825         105
# 638        1528  893086          The Good Neighbor         6.952         105
# 639        1532  639247               Dreamkatcher         5.231         104
# 640        1539  727097                  Archenemy         5.306         103
# 641        1548  876969              Assassin Club         6.162         102
#
# ...

# %%
df2= pd.read_csv('../data_cleaned/cleaned_Highest Holywood Grossing Movies.csv')

# %%
df2
# Out:
#      Unnamed: 0  unnamed:_0                                       title  \
# 0             0           0                                      Avatar
# 1             1           1                           Avengers: Endgame
# 2             2           2                    Avatar: The Way of Water
# 3             3           3                                     Titanic
# 4             4           4  Star Wars: Episode VII - The Force Awakens
# ..          ...         ...                                         ...
# 974         995         995                          Sweet Home Alabama
# 975         996         996                              Daddy's Home 2
# 976         997         997                               Hacksaw Ridge
# 977         998         998                                     Deja Vu
# 978         999         999                                       M3GAN
#
#                                             movie_info  year  \
# ...

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'unnamed:_0', 'title', 'movie_info', 'year',
#        'distributor', 'budget_(in_$)', 'domestic_opening_(in_$)',
#        'domestic_sales_(in_$)', 'international_sales_(in_$)',
#        'world_wide_sales_(in_$)', 'release_date', 'genre', 'running_time',
#        'license'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'id', 'title', 'vote_average', 'vote_count', 'status',
#        'release_date', 'revenue', 'runtime', 'adult', 'budget', 'imdb_id',
#        'original_language', 'popularity', 'genres', 'production_companies',
#        'production_countries', 'spoken_languages'],
#       dtype='object')

# %%
df2.isna().sum()
# Out:
# Unnamed: 0                    0
# unnamed:_0                    0
# title                         0
# movie_info                    0
# year                          0
# distributor                   0
# budget_(in_$)                 0
# domestic_opening_(in_$)       0
# domestic_sales_(in_$)         0
# international_sales_(in_$)    0
# world_wide_sales_(in_$)       0
# release_date                  0
# genre                         0
# running_time                  0
# license                       0
# dtype: int64

# %%
result_df = pd.merge(df1, df2[['title', 'license']], on='title',how='left')

# %%
result_df
# Out:
#      Unnamed: 0      id                      title  vote_average  vote_count  \
# 0             0  299534          Avengers: Endgame         8.263       23857
# 1             1  475557                      Joker         8.168       23425
# 2             2  634649    Spider-Man: No Way Home         7.990       18299
# 3             3  299537             Captain Marvel         6.843       14657
# 4             4  429617  Spider-Man: Far From Home         7.447       14495
# ..          ...     ...                        ...           ...         ...
# 641        1527  884184               Consecration         5.825         105
# 642        1528  893086          The Good Neighbor         6.952         105
# 643        1532  639247               Dreamkatcher         5.231         104
# 644        1539  727097                  Archenemy         5.306         103
# 645        1548  876969              Assassin Club         6.162         102
#
# ...

# %%
result_df.isna().sum()
# Out:
# Unnamed: 0                0
# id                        0
# title                     0
# vote_average              0
# vote_count                0
# status                    0
# release_date              0
# revenue                   0
# runtime                   0
# adult                     0
# budget                    0
# imdb_id                   0
# original_language         0
# popularity                0
# genres                    0
# production_companies      0
# production_countries      0
# spoken_languages          0
# license                 546
# dtype: int64

# %%
result_df.fillna('U')
# Out:
#      Unnamed: 0      id                      title  vote_average  vote_count  \
# 0             0  299534          Avengers: Endgame         8.263       23857
# 1             1  475557                      Joker         8.168       23425
# 2             2  634649    Spider-Man: No Way Home         7.990       18299
# 3             3  299537             Captain Marvel         6.843       14657
# 4             4  429617  Spider-Man: Far From Home         7.447       14495
# ..          ...     ...                        ...           ...         ...
# 641        1527  884184               Consecration         5.825         105
# 642        1528  893086          The Good Neighbor         6.952         105
# 643        1532  639247               Dreamkatcher         5.231         104
# 644        1539  727097                  Archenemy         5.306         103
# 645        1548  876969              Assassin Club         6.162         102
#
# ...

# %%
result_df.to_csv('../data_cleaned/cleaned_merged_df')
