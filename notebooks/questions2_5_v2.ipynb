# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('../data_cleaned/merged_data.csv')

# %%
df
# Out:
#      Unnamed: 0      id                      title  vote_average  vote_count  \
# 0             0  299534          Avengers: Endgame         8.263       23857
# 1             1  475557                      Joker         8.168       23425
# 2             2  634649    Spider-Man: No Way Home         7.990       18299
# 3             3  299537             Captain Marvel         6.843       14657
# 4             4  429617  Spider-Man: Far From Home         7.447       14495
# ..          ...     ...                        ...           ...         ...
# 636         647  884184               Consecration         5.825         105
# 637         648  893086          The Good Neighbor         6.952         105
# 638         649  639247               Dreamkatcher         5.231         104
# 639         650  727097                  Archenemy         5.306         103
# 640         651  876969              Assassin Club         6.162         102
#
#        status release_date     revenue  runtime  adult  ...     imdb_id  \
# 0    Released   2019-04-24  2800000000      181  False  ...   tt4154796
# 1    Released   2019-10-01  1074458282      122  False  ...   tt7286456
# 2    Released   2021-12-15  1921847111      148  False  ...  tt10872600
# 3    Released   2019-03-06  1131416446      124  False  ...   tt4154664
# 4    Released   2019-06-28  1131927996      129  False  ...   tt6320628
# ..        ...          ...         ...      ...    ...  ...         ...
# 636  Released   2023-02-09     1504289       90  False  ...  tt14993352
# 637  Released   2022-06-17       94909       97  False  ...  tt14349032
# 638  Released   2020-06-24      375836       85  False  ...  tt10553210
# 639  Released   2020-11-30      136240       90  False  ...  tt11274100
# 640  Released   2023-02-24      188292      113  False  ...   tt7720142
#
#     original_language popularity     genres  \
# 0                  en     91.756  Adventure
# 1                  en     54.522      Crime
# 2                  en    186.065     Action
# 3                  en     50.399     Action
# 4                  en     49.913     Action
# ..                ...        ...        ...
# 636                en     48.774     Horror
# 637                en     13.842   Thriller
# 638                en      7.720     Horror
# 639                en      8.290     Action
# 640                en     36.325     Action
#
#                                   production_companies  \
# 0                                       Marvel Studios
# 1    Warner Bros. Pictures, Joint Effort, Village R...
# 2    Marvel Studios, Pascal Pictures, Columbia Pict...
# 3                                       Marvel Studios
# 4    Marvel Studios, Pascal Pictures, Columbia Pict...
# ..                                                 ...
# 636     AGC Studios, Bigscope Films, Moonriver Content
# 637                 Forma Pro Films, Altit Media Group
# 638                            Taylor Lane Productions
# 639  SpectreVision, Legion M, RLJ Entertainment, He...
# 640       Film Bridge International, The Motus Studios
#
#                          production_countries  \
# 0                    United States of America
# 1            Canada, United States of America
# 2                    United States of America
# 3                    United States of America
# 4                    United States of America
# ..                                        ...
# 636  United Kingdom, United States of America
# 637          United States of America, Latvia
# 638                  United States of America
# 639                  United States of America
# 640           Italy, United States of America
#
#                            spoken_languages film_oscar_nominee  \
# 0                  English, Japanese, Xhosa                1.0
# 1                                   English                1.0
# 2                          English, Tagalog                1.0
# 3                                   English                0.0
# 4    Czech, Dutch, English, German, Italian                0.0
# ..                                      ...                ...
# 636                                 English                0.0
# 637                                 English                0.0
# 638                                 English                0.0
# 639                                 English                0.0
# 640                                 English                0.0
#
#      company_nominated  license
# 0                    0    PG-13
# 1                    1        R
# 2                    0    PG-13
# 3                    0    PG-13
# 4                    0  unknown
# ..                 ...      ...
# 636                  0  unknown
# 637                  0  unknown
# 638                  0  unknown
# 639                  0  unknown
# 640                  0  unknown
#
# [641 rows x 21 columns]

# %%
df.isna().sum()
# Out:
# Unnamed: 0              0
# id                      0
# title                   0
# vote_average            0
# vote_count              0
# status                  0
# release_date            0
# revenue                 0
# runtime                 0
# adult                   0
# budget                  0
# imdb_id                 0
# original_language       0
# popularity              0
# genres                  0
# production_companies    0
# production_countries    0
# spoken_languages        0
# film_oscar_nominee      0
# company_nominated       0
# license                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'title', 'vote_average', 'vote_count', 'status',
#        'release_date', 'revenue', 'runtime', 'adult', 'budget', 'imdb_id',
#        'original_language', 'popularity', 'genres', 'production_companies',
#        'production_countries', 'spoken_languages', 'film_oscar_nominee',
#        'company_nominated', 'license'],
#       dtype='object')

# %% [markdown]
# # Which movie genres are most popular among audiences during this period?

# %%
unique_genres = df['genres'].unique()
print("Unique Genres:", unique_genres)
# Out:
# Unique Genres: ['Adventure' 'Crime' 'Action' 'Comedy' 'War' 'Science Fiction' 'Animation'
#  'Family' 'Horror' 'Fantasy' 'Thriller' 'Romance' 'Drama' 'Music'
#  'Mystery' 'History' 'Documentary' 'Western']

# %%
genre_counts = df['genres'].value_counts()

# %%
plt.figure(figsize=(10, 6))
genre_counts.plot(kind='bar', color='skyblue')
plt.title('Genre Distribution')
plt.xlabel('Genres')
plt.ylabel('Number of Movies')
plt.xticks(rotation=45, ha='right')  
plt.show()

# %%
average_ratings = df.groupby('genres')['vote_average'].mean()

plt.figure(figsize=(10, 6))
average_ratings.sort_values(ascending=False).plot(kind='bar', color='salmon')
plt.title('Average Ratings by Genre')
plt.xlabel('Genres')
plt.ylabel('Average Rating')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
revenue_trends = df.groupby('genres')['revenue'].mean()

plt.figure(figsize=(10, 6))
revenue_trends.sort_values(ascending=False).plot(kind='bar', color='lightgreen')
plt.title('Average Revenue by Genre')
plt.xlabel('Genres')
plt.ylabel('Average Revenue (in billions)')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# # Explore how the popularity of different genres has changed over the years

# %%
df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce')  
df['Year'] = df['release_date'].dt.year

print("Year distribution:\n", df['Year'].value_counts())

df = df[df['Year'].between(2019, 2023)]

filtered_genres = ['Adventure', 'Action', 'Science Fiction', 'Animation', 'Family', 'Fantasy']
filtered_df = df[df['genres'].isin(filtered_genres)]

if filtered_df.empty:
    print("No data available for the specified years and genres.")
else:

    plt.figure(figsize=(10, 6))
    sns.lineplot(data=filtered_df, x='Year', y='vote_average', hue='genres')

    plt.title('Popularity Trends of Various Movie Genres (2019-2023)')
    plt.xlabel('Year')
    plt.ylabel('Vote Average')
    plt.legend(title='Genre')
    plt.show()
# Out:
# Year distribution:
#  Year
# 2019    193
# 2021    135
# 2020    127
# 2022    117
# 2023     69
# Name: count, dtype: int64

# %% [markdown]
# # Investigate whether there are specific ratings that yield higher box office revenue.

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['vote_average'], df['revenue'], color='purple', alpha=0.5)
plt.title('Scatter Plot of Box Office Revenue vs. Vote Average')
plt.xlabel('Vote Average')
plt.ylabel('Box Office Revenue (in billions)')
plt.show()

# %%
correlation = df['vote_average'].corr(df['revenue'])
print(f'Correlation between Vote Average and Revenue: {correlation}')
# Out:
# Correlation between Vote Average and Revenue: 0.3155158562260486

# %%
df.to_csv('../data_cleaned/questions2_5_v2.csv')
