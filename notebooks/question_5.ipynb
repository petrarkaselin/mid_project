# %%
# Are Oscars nominated production companies  consistently associated with high-performing movies?
# Compare revenue between movies that were produced by these companies and the rest of movies realeased in 2023.

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv('../data_cleaned/merged_data.csv')

data['release_date'] = pd.to_datetime(data['release_date'], errors='coerce')

movies_2022 = data[data['release_date'].dt.year == 2022]

# %%
movies_2022
# Out:
#      Unnamed: 0      id                                        title  \
# 8             8   76600                     Avatar: The Way of Water
# 26           28  414906                                   The Batman
# 31           33  453395  Doctor Strange in the Multiverse of Madness
# 40           42  361743                            Top Gun: Maverick
# 48           50  616037                       Thor: Love and Thunder
# ..          ...     ...                                          ...
# 612         623  843380                            Dead for a Dollar
# 614         625  850028                               Alice, Darling
# 622         633  823147                                    To Leslie
# 628         639  747803                                      One Way
# 637         648  893086                            The Good Neighbor
#
#      vote_average  vote_count    status release_date     revenue  runtime  \
# 8           7.654        9830  Released   2022-12-14  2320250281      192
# 26          7.705        8584  Released   2022-03-01   770945583      177
# 31          7.355        7991  Released   2022-05-04   955775804      126
# 40          8.260        7546  Released   2022-05-24  1488732821      131
# 48          6.517        6510  Released   2022-07-06   760928081      119
# ..            ...         ...       ...          ...         ...      ...
# 612         5.680         136  Released   2022-09-30       81403      106
# 614         5.878         135  Released   2022-12-30      121067       90
# 622         7.125         128  Released   2022-10-07       27322      119
# 628         6.100         115  Released   2022-09-02       30272       96
# 637         6.952         105  Released   2022-06-17       94909       97
#
#      adult  ...     imdb_id original_language popularity           genres  \
# 8    False  ...   tt1630029                en    241.285  Science Fiction
# 26   False  ...   tt1877830                en    100.817            Crime
# 31   False  ...   tt9419884                en     96.530          Fantasy
# 40   False  ...   tt1745960                en    126.291           Action
# 48   False  ...  tt10648342                en    117.087          Fantasy
# ..     ...  ...         ...               ...        ...              ...
# 612  False  ...  tt14895206                en     29.912          Western
# 614  False  ...  tt11687104                en     15.812         Thriller
# 622  False  ...   tt8129806                en     13.290            Drama
# 628  False  ...  tt13075730                en     18.822           Action
# 637  False  ...  tt14349032                en     13.842         Thriller
#
#                                   production_companies  \
# 8       20th Century Studios, Lightstorm Entertainment
# 26   6th & Idaho, Dylan Clark Productions, DC Films...
# 31             Marvel Studios, Kevin Feige Productions
# 40   Skydance, Don Simpson/Jerry Bruckheimer Films,...
# 48             Marvel Studios, Kevin Feige Productions
# ..                                                 ...
# 612            Chaos, a Film Company, Polaris Pictures
# 614  Babe Nation Films, Elevation Pictures, Castell...
# 622  BCDF Pictures, Baral Waley Productions, Shaken...
# 628  Highland Film Group, Bay Point Media, 23ten, P...
# 637                 Forma Pro Films, Altit Media Group
#
#                                   production_countries  \
# 8                             United States of America
# 26                            United States of America
# 31                            United States of America
# 40                            United States of America
# 48                            United States of America
# ..                                                 ...
# 612                   Canada, United States of America
# 614                   Canada, United States of America
# 622                           United States of America
# 628  Ireland, United Kingdom, United States of America
# 637                   United States of America, Latvia
#
#                 spoken_languages film_oscar_nominee  company_nominated  \
# 8                        English                1.0                  0
# 26                       English                1.0                  1
# 31   Cantonese, English, Spanish                0.0                  0
# 40                       English                1.0                  1
# 48                       English                0.0                  0
# ..                           ...                ...                ...
# 612                      English                0.0                  0
# 614                      English                0.0                  0
# 622                      English                1.0                  0
# 628                      English                0.0                  0
# 637                      English                0.0                  0
#
#      license
# 8      PG-13
# 26     PG-13
# 31     PG-13
# 40     PG-13
# 48     PG-13
# ..       ...
# 612  unknown
# 614  unknown
# 622  unknown
# 628  unknown
# 637  unknown
#
# [117 rows x 21 columns]

# %%
columns_to_drop = ['Unnamed: 0',	
                   'id',	
                   'vote_average',	
                   'vote_count',	
                   'status',	
                   'runtime',	
                   'adult', 
                   'imdb_id',	
                   'original_language',	
                   'popularity',	
                   'genres',
                   'production_countries',	
                   'spoken_languages',	
                   'film_oscar_nominee',
                   'license',
                   'budget']
movies_2022 = movies_2022.drop(columns=columns_to_drop)

# %%
def keep_first_word(string):
    return string.split(',')[0]
movies_2022['production_companies'] = movies_2022['production_companies'].apply(keep_first_word)
movies_2022.head()
# Out:
#                                           title release_date     revenue  \
# 8                      Avatar: The Way of Water   2022-12-14  2320250281
# 26                                   The Batman   2022-03-01   770945583
# 31  Doctor Strange in the Multiverse of Madness   2022-05-04   955775804
# 40                            Top Gun: Maverick   2022-05-24  1488732821
# 48                       Thor: Love and Thunder   2022-07-06   760928081
#
#     production_companies  company_nominated
# 8   20th Century Studios                  0
# 26           6th & Idaho                  1
# 31        Marvel Studios                  0
# 40              Skydance                  1
# 48        Marvel Studios                  0

# %%
movies_2022.head()
# Out:
#                                           title release_date     revenue  \
# 8                      Avatar: The Way of Water   2022-12-14  2320250281
# 26                                   The Batman   2022-03-01   770945583
# 31  Doctor Strange in the Multiverse of Madness   2022-05-04   955775804
# 40                            Top Gun: Maverick   2022-05-24  1488732821
# 48                       Thor: Love and Thunder   2022-07-06   760928081
#
#     production_companies  company_nominated
# 8   20th Century Studios                  0
# 26           6th & Idaho                  1
# 31        Marvel Studios                  0
# 40              Skydance                  1
# 48        Marvel Studios                  0

# %%
movies_2022_describe = movies_2022.describe()
movies_2022['revenue_M'] = movies_2022['revenue']/1000000

# %%
revenue_median = movies_2022['revenue'].quantile(0.5)
revenue_median
# Out:
# 24733572.0

# %%
movies_2022.head()
# Out:
#                                           title release_date     revenue  \
# 8                      Avatar: The Way of Water   2022-12-14  2320250281
# 26                                   The Batman   2022-03-01   770945583
# 31  Doctor Strange in the Multiverse of Madness   2022-05-04   955775804
# 40                            Top Gun: Maverick   2022-05-24  1488732821
# 48                       Thor: Love and Thunder   2022-07-06   760928081
#
#     production_companies  company_nominated    revenue_M
# 8   20th Century Studios                  0  2320.250281
# 26           6th & Idaho                  1   770.945583
# 31        Marvel Studios                  0   955.775804
# 40              Skydance                  1  1488.732821
# 48        Marvel Studios                  0   760.928081

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
sns.barplot(x='company_nominated', y='revenue_M', data=movies_2022, estimator='mean')
plt.axhline(y=revenue_median/1000000, color='red', linestyle='--', label='Median Revenue')
plt.title('Mean Revenue by Company Nomination')
plt.xlabel('Company Nomination')
plt.ylabel('Mean Revenue (M)')
plt.show()

# %%
# 2_sample t-test. H0: mean_revenue_1 >

# %%
movies_2022
# Out:
#                                            title release_date     revenue  \
# 8                       Avatar: The Way of Water   2022-12-14  2320250281
# 26                                    The Batman   2022-03-01   770945583
# 31   Doctor Strange in the Multiverse of Madness   2022-05-04   955775804
# 40                             Top Gun: Maverick   2022-05-24  1488732821
# 48                        Thor: Love and Thunder   2022-07-06   760928081
# ..                                           ...          ...         ...
# 612                            Dead for a Dollar   2022-09-30       81403
# 614                               Alice, Darling   2022-12-30      121067
# 622                                    To Leslie   2022-10-07       27322
# 628                                      One Way   2022-09-02       30272
# 637                            The Good Neighbor   2022-06-17       94909
#
#      production_companies  company_nominated    revenue_M
# 8    20th Century Studios                  0  2320.250281
# 26            6th & Idaho                  1   770.945583
# 31         Marvel Studios                  0   955.775804
# 40               Skydance                  1  1488.732821
# 48         Marvel Studios                  0   760.928081
# ..                    ...                ...          ...
# 612                 Chaos                  0     0.081403
# 614     Babe Nation Films                  0     0.121067
# 622         BCDF Pictures                  0     0.027322
# 628   Highland Film Group                  0     0.030272
# 637       Forma Pro Films                  0     0.094909
#
# [117 rows x 6 columns]

# %%
movies_2022.to_csv('../data_cleaned/question_6.csv')
